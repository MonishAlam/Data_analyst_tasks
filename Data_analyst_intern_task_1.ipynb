# %%
import pandas as pd

# %%
df = pd.read_csv("Netflix_movies_and_tv_shows_Data.csv")
df
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
nulldf = df.isnull()
nulldf
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False      True  False    False       False
# 1       False  False  False     False  False    False       False
# 2       False  False  False     False  False    False       False
# 3       False  False  False     False  False    False       False
# 4       False  False  False     False  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 7782    False  False  False     False  False    False       False
# 7783    False  False  False     False  False    False       False
# 7784    False  False  False      True  False     True       False
# 7785    False  False  False      True  False    False       False
# 7786    False  False  False     False   True    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
dup_df = df.drop_duplicates()
dup_df
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
standar_by_country_df= df.sort_values("country")
standar_by_country_df
# Out:
#      show_id     type                            title               director  \
# 4746   s4747    Movie                Palermo Hollywood          Eduardo Pinto
# 4495   s4496  TV Show                No Time for Shame                    NaN
# 1167   s1168    Movie                  Caida del Cielo  Néstor Sánchez Sotelo
# 1221   s1222  TV Show  Carmel: Who Killed Maria Marta?     Alejandro Hartmann
# 4220   s4221  TV Show          Monzón: A Knockout Blow                    NaN
# ...      ...      ...                              ...                    ...
# 7739   s7740    Movie                  Your Excellency         Funke Akindele
# 7746   s7747  TV Show                     دفعة القاهرة                    NaN
# 7765   s7766    Movie                        Zero Hour       Robert O. Peters
# 7777   s7778  TV Show                      Zombie Dumb                    NaN
# 7784   s7785    Movie                Zulu Man in Japan                    NaN
#
# ...

# %%
standar_By_year_df= df.sort_values("release_year")
standar_By_year_df
# Out:
#      show_id     type                                          title  \
# 4867   s4868  TV Show              Pioneers: First Women Filmmakers*
# 6117   s6118    Movie                           The Battle of Midway
# 4960   s4961    Movie                                 Prelude to War
# 7679   s7680    Movie                WWII: Report from the Aleutians
# 7342   s7343    Movie  Undercover: How to Operate Behind Enemy Lines
# ...      ...      ...                                            ...
# 4173   s4174  TV Show                                        Monarca
# 3822   s3823  TV Show                                          Lupin
# 980     s981  TV Show                                   Bling Empire
# 1285   s1286    Movie                                       Charming
# 4468   s4469  TV Show    Night Stalker: The Hunt for a Serial Killer
#
#             director                                               cast  \
# ...

# %%
import pandas as pd

# %%
df1 = pd.read_csv('Netflix_movies_and_tv_shows_Data.csv')
df1['date_added'] = pd.to_datetime(df1['date_added'], format='%B %d, %Y', errors='coerce')
# Reformat date to DD/MM/YYYY
df1['date_added'] = df1['date_added'].dt.strftime('%d/%m/%Y')
# Save to new CSV (optional)
df1.to_csv('formatted_netflix.csv', index=False)

# %%
format_df = pd.read_csv("formatted_netflix.csv")
format_df
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
#I am performing operation in df.
new_df = df.rename(columns={"show_id":"ShowID", "type":"Type", "title":"Names", "listed_in": "Watch_On"})
new_df
# Out:
#      ShowID     Type                                    Names  \
# 0        s1  TV Show                                       3%
# 1        s2    Movie                                     7:19
# 2        s3    Movie                                    23:59
# 3        s4    Movie                                        9
# 4        s5    Movie                                       21
# ...     ...      ...                                      ...
# 7782  s7783    Movie                                     Zozo
# 7783  s7784    Movie                                   Zubaan
# 7784  s7785    Movie                        Zulu Man in Japan
# 7785  s7786  TV Show                    Zumbo's Just Desserts
# 7786  s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df.info()#.info() is use for checking the information about dataset
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7787 non-null   int64
#  8   rating        7780 non-null   object
#  9   duration      7787 non-null   object
#  10  listed_in     7787 non-null   object
#  11  description   7787 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 730.2+ KB
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# ...
